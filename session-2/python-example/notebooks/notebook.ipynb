# %% [markdown]
# ## Test OpenAI code

# %%
from pathlib import Path
import pandas as pd

# %%
path = Path("../tests/sample-10.csv")
assert path.exists()
df = pd.read_csv(path)

# %%
df.head()
# Out:
#        id       length                                       newspaper  \
# 0  171631    431 words           The Telegraph-Journal (New Brunswick)
# 1   90704    743 words                              The New York Times
# 2  140288    657 words                   Portland Press Herald (Maine)
# 3  143623  1042  words           News-Journal (Daytona Beach, Florida)
# 4   59022    838 words  Distributed by McClatchy-Tribune Business News
#
#                                        section  \
# 0                                 MAIN; Pg. A3
# 1  Section A; Page 17, Column 1; National Desk
# 2                        LOCAL & STATE; Pg. B1
# 3                            NEIGHBORS; Pg. 2S
# 4                      STATE AND REGIONAL NEWS
#
#                                                title  year  \
# 0     Music festival to raise funds for nature trust  2012
# 1  E.P.A. Office Recommends Against Dam Project N...  1990
# 2  Dirigo proposal stirs up concern; State House:...  2006
# ...

# %%
text = df['text'][0]
